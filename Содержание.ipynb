# %% [markdown]
# # <u>Содержание:</u>
# ## <u> [Книга](<./Python для аналитики данных.pdf>)</u>
# ### МОДУЛЬ 1. Python для анализа данных. Основы и инструменты
# * [ЗАНЯТИЕ 1. Базовые инструменты аналитики. Настройка окружения](<./М1. Основы Python/1. Базовые инструменты аналитики. Настройка окружения/ЗАНЯТИЕ 1.pdf>)
# * [ЗАНЯТИЕ 2. Синтаксис, типы, функции, цикл while и условные выражения](<./М1. Основы Python/2. Синтаксис, типы, функции, цикл while и условные выражения/ЗАНЯТИЕ 2.ipynb>)
# * [ЗАНЯТИЕ 3. Наборы данных, цикл for, ООП, работа с файлами и исключения](<./М1. Основы Python/3. Наборы данных, цикл for, ООП, работа с файлами и исключения/ЗАНЯТИЕ 3.ipynb>)
# * [ЗАНЯТИЕ 4. Стандартные библиотеки](<./М1. Основы Python/4. Стандартные библиотеки/ЗАНЯТИЕ 4.ipynb>)
#
# ### МОДУЛЬ 2. Работа с массивами данных
# * [ЗАНЯТИЕ 5. Библиотека NumPy](<./М2. Работа с массивами данных/5. Библиотека NumPy/ЗАНЯТИЕ 5.ipynb>)
# * [ЗАНЯТИЕ 6. Библиотека pandas](<./М2. Работа с массивами данных/6. Библиотека pandas/ЗАНЯТИЕ 6.ipynb>)
#
# ### МОДУЛЬ 3. Статистика в Python
# * [ЗАНЯТИЕ 7. Статистика в NumPy и в Statistics. Введение в Scipy.Stats](<./М3. Статистика в Python/7. Статистика в NumPy и в Statistics. Введение в Scipy.Stats/ЗАНЯТИЕ 7.ipynb>)
# * [ЗАНЯТИЕ 8. Scipy. Примеры статистики, z-статистика и p-value](<./М3. Статистика в Python/8. Scipy. Примеры статистики, z-статистика и p-value/ЗАНЯТИЕ 8.ipynb>)
#
# ### МОДУЛЬ 4. Введение в SQL и метрики данных
# * [ЗАНЯТИЕ 9. SQL - язык для работы с базами данных (на примере SQLite)](<./М4. Введение в SQL и метрики/9. SQL - язык для работы с базами данных (на примере SQLite)/ЗАНЯТИЕ 9.ipynb>)
# * [ЗАНЯТИЕ 10. Метрики (на примере ключевых продуктовых метрик)](<./М4. Введение в SQL и метрики/10. Метрики (на примере ключевых продуктовых метрик)/ЗАНЯТИЕ 10.ipynb>)
#
# ### МОДУЛЬ 5. Машинное обучение (аналитика больших данных)
# * [ЗАНЯТИЕ 11. TensorFlow Keras. Решение математических задач](<./М5. Машинное обучение/11. TensorFlow Keras. Решение математических задач/ЗАНЯТИЕ 11.ipynb>)
# * [ЗАНЯТИЕ 12. TensorFlow Keras. Классификация изображений](<./М5. Машинное обучение/12. TensorFlow Keras. Классификация изображений/ЗАНЯТИЕ 12.ipynb>)
# * [ЗАНЯТИЕ 13. Библиотека Scikit-learn. Обучение с учителем и без учителя](<./М5. Машинное обучение/13. Библиотека Scikit-learn. Обучение с учителем и без учителя/ЗАНЯТИЕ 13.ipynb>)
